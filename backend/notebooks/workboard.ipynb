# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, TextIteratorStreamer
from threading import Thread

# %%
model_name_or_path = "TheBloke/Mistral-7B-Instruct-v0.1-GPTQ"
model = AutoModelForCausalLM.from_pretrained(
model_name_or_path,
            device_map="auto",
            trust_remote_code=False,
            revision="gptq-4bit-32g-actorder_True",
        ).cuda()
# Out:
# Downloading model.safetensors: 100%|██████████| 4.57G/4.57G [03:11<00:00, 23.9MB/s]
# Downloading (…)neration_config.json: 100%|██████████| 116/116 [00:00<00:00, 744kB/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(
            model_name_or_path, use_fast=True
        )
streamer = TextIteratorStreamer(
            tokenizer, timeout=20.0, skip_prompt=True, skip_special_tokens=True
        )
# Out:
# Downloading (…)okenizer_config.json: 100%|██████████| 1.46k/1.46k [00:00<00:00, 7.79MB/s]
# Downloading tokenizer.model: 100%|██████████| 493k/493k [00:00<00:00, 294MB/s]
# Downloading (…)/main/tokenizer.json: 100%|██████████| 1.80M/1.80M [00:00<00:00, 3.91MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 72.0/72.0 [00:00<00:00, 319kB/s]

# %%
device = "cuda"
messages = [
    {"role": "user", "content": "What is your favourite condiment?"},
    {"role": "assistant", "content": "Well, I'm quite partial to a good squeeze of fresh lemon juice. It adds just the right amount of zesty flavour to whatever I'm cooking up in the kitchen!"},
    {"role": "user", "content": "Do you have mayonnaise recipes?"}
]

# %%
encodeds = tokenizer.apply_chat_template(
            messages, return_tensors="pt"
        )
model_inputs = encodeds.to(device)

generate_kwargs = dict(
    inputs=model_inputs,
    max_new_tokens=512,
    do_sample=True,
    top_p=0.95,
    top_k=40,
    temperature=0.7,
    streamer=streamer,
)

t = Thread(target=model.generate, kwargs=generate_kwargs)
t.start()

for new_text in streamer:
    print(new_text)
# Out:
# /home/danlin/Projects/masters-project/masters/lib/python3.10/site-packages/transformers/generation/utils.py:1421: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Certainly!
#
#
# Here's
# a
# simple
# recipe
# for
#
# homemade
#
#
# mayonnaise
# that
# I
# think
#
#
# you'll
#
# enjoy:
#
#
#
#
#
#
#
#
# Ingredients:
#
#
# -
#
# 2
# large
# egg
#
#
# yolks
#
#
# -
#
# 1
#
# tablespoon
#
#
# Dijon
#
# mustard
#
#
# -
#
# 2
#
#
# tablespoons
# white
# wine
#
# vinegar
#
#
# -
#
#
#
# 1/2
#
# teaspoon
# salt
#
#
# -
#
#
#
# 1/4
#
# teaspoon
# sugar
#
#
# -
#
# 1
# cup
#
# vegetable
# oil
#
#
#
#
#
#
# Instructions:
#
#
#
# 1.
# In
# a
#
# blender
# or
# food
#
# processor,
# combine
# the
# egg
#
#
#
# yolks,
#
#
# Dijon
#
#
# mustard,
# white
# wine
#
#
# vinegar,
#
# salt,
# and
#
# sugar.
#
# Blend
# until
#
# smooth.
#
#
#
# 2.
# With
# the
#
# blender
# or
# food
# processor
#
# running,
# slowly
# pour
# in
# the
#
# vegetable
# oil
# in
# a
# steady
#
# stream,
# making
# sure
# to
# blend
# continuously
# until
# the
# oil
# has
# fully
#
# incorporated.
#
#
#
# 3.
# Once
# the
#
#
# mayonnaise
# has
# reached
# your
# desired
#
# consistency,
# transfer
# it
# to
# a
# jar
# and
#
# refrigerate
# for
# at
# least
# an
# hour
# before
#
# serving.
#
#
#
#
# This
#
# homemade
#
#
# mayonnaise
# is
# perfect
# for
#
#
#
# sandwiches,
#
#
# salads,
# and
# as
# a
#
# dipping
# sauce
# for
#
# vegetables.
#
#
# Enjoy!
